# %%
# Warmup 1: 1st way to use import

# on the line below, import the time module


start_time = time.time()
x = 2**1000000000
end_time = time.time()

#change the line below to compute difference
difference = 0

# add a separator of '\n'
print(start_time, end_time, difference)
# Out:
# 1643990534.650444
# 1643990542.573494
# 0

# %%
# Warmup 2: 2nd way to use import
# TODO: from the math module, just import the function log10()



# then, print the log base 10 of 1000
# Out:
# 3.0

# %%
# Note: importing with 'wildcard' * is generally considered bad practice
from math import *  #allows us to use all functions without writing math._____
print(pi)
# Out:
# 3.141592653589793

# %%
# Warmup 3: Using the preferred way, import just randint from random.
# Then, print out a random integer between 7 and 9

# import ?????
# print(???)

# %% [markdown]
# # Lecture 6: Writing Functions
# ### Learning Objectives:
#
# - Explain the syntax of a function header.
# -Write a function
#  - with a correct header and indentation.
#  - with a return value (fruitful function) or without (void function).
#  - with one or more parameters that have default values
#  - knowing the difference in outcomes of print and return statements.
# - Make function calls using positional, keyword, and default arguments and determine the result.
# - Override the default arguments of the `print` function
# - Trace function invocations to determine the flow of control

# %% [markdown]
# ### Explain the syntax of a function header

# %%
# A function gives a name to a block of code. 
# A function can store inputs in parameters
# A function definition starts with the word `def`

# %% [markdown]
# ![Screen%20Shot%202022-09-19%20at%208.51.43%20AM.png](attachment:Screen%20Shot%202022-09-19%20at%208.51.43%20AM.png)

# %% [markdown]
# ### Write a function

# %%
# Example 1:  write a function that cubes any number



# the first line is called the header
# notice that all the other lines are indented the same amount (4 spaces)
# best practice in Jupyter Notebook is to press tab
# if you don't run the cell Jupyter Notebook won't know about the function

# %%
# calling a function
print(cube(5))
print(cube(4) + cube(-3))
print(cube(cube(2)))
# Out:
# 125
# 37
# 512

# %% [markdown]
# ### If you know you will need the result of a function call again..... save it to a variable

# %%
# given two numbers, find the sum, difference, and product of their cubes
print(cube(9) + cube(7))
print(cube(9) - cube(7))
print(cube(9) * cube(7))
# Out:
# 1072
# 386
# 250047

# %%
# better way:  
# first make variables to save the result of each function call

# then in the print statements, use the variable
print(cube(9) + cube(7))
print(cube(9) - cube(7))
print(cube(9) * cube(7))

# %% [markdown]
# ### Understand the difference between a print and a return in a function
#
# print() does not end a function.
#
# print() does not send a value back that can be stored and used

# %%
# up above, change return to print(),  

# then re-run the cell calling a function

# Explain what goes wrong in those function calls in the above cell

# %% [markdown]
# ### Write a Function that returns a boolean

# %%
# Example 2:  Write a function that determines if one number is between two other numbers
# return a boolean ... True or False
def is_between(lower, num, upper):
    pass

# you can call a function in the same cell that you defined it
print(is_between(3, 7, 21))
print(is_between(2, 14, 5))
print(is_between(100,  cube(5), 200))
# Out:
# True
# False

# %% [markdown]
# ### Write a Function that returns a string

# %%
# Example 3: write a function make_grid that works like this:
# make_grid(5, 3, "@") returns the string 
# @@@@@
# @@@@@
# @@@@@

# Let's practice Incremental Coding
# first, try to do this with string operators and literals

# %%
# then, try to do this with variables

# %%
# now, try to write a function 
# think about what we should name the parameters

def get_grid():
    pass

print(get_grid(3, 5, "*"))

# %%
# test again

# %%
# Now, add in a parameter for a title that appears above the grid
# test again

# %%
# Finally, add in default arguments
# test again

# %% [markdown]
# ### Make function calls using positional, default, and keyword arguments and determine the result.

# %% [markdown]
# ![Screen%20Shot%202022-09-19%20at%208.54.57%20AM.png](attachment:Screen%20Shot%202022-09-19%20at%208.54.57%20AM.png)

# %%
def add3(x,y=100,z=100): # parameters are x, y, z
    """adds three numbers""" #documentation string
    print ("y=" + str(y))
    return x+y+z

sum = add3(100,10,5) #positional arguments
# Out:
# y=10

# %%
#print(add3(4,2,1)**2)
# Out:
# y=2
# 49

# %%
#print(add3(x=1, z=2, y=5)) #keyword arguments

# %%
#add3(5,6)   #using a default argument

# %%
# incorrect use of arguments in function calls
# add3(z=5, 2, 7) 

# Explain why:

# %%
# other incorrect uses
# add3(5, 3, x=4)

# Explain why:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-6a537f082c51> in <module>
#       1 # other incorrect uses
# ----> 2 add3(5, 3, x=4)
#
# TypeError: add3() got multiple values for argument 'x'

# %%
# also incorrect
# add3(y=5,z=10)
# Explain why
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-f7882f64214a> in <module>
# ----> 1 add3(y=5,z=10)
#
# TypeError: add3() missing 1 required positional argument: 'x'

# %%
# also incorrect
# add3()
# Explain why
# Out:
# -------------------------------------------------
# TypeError       Traceback (most recent call last)
# <ipython-input-19-a0655df593d7> in <module>
# ----> 1 add3()
#
# TypeError: add3() missing 1 required positional argument: 'x'

# %%
# works
add3(3)
# Explain why
# Out:
# y=100
# 203

# %% [markdown]
# ![kinds%20of%20arguments.png](attachment:kinds%20of%20arguments.png)

# %%
# make several calls to get_grid using positional, keyword, and default arguments

# %% [markdown]
# ### Override the default arguemnts for the print() function

# %%
# What are the default arguments for print? 
# help(print)

# %%
# Predict the output, then uncomment and run 
# print(3+4, 3<4, "3"+"4",  end="...." )     # sep default is " "

# print(3+4, 3<4, "3"+"4", sep="\t" )        # end default is "\n"

# %% [markdown]
# ### Know the difference in outcomes of print and return statements.

# %%
def bad_add(x,y,z): #doesn't return a value...void function
    print (x)
    print(x+y+z)
print(bad_add(3, 5, 10))
# Out:
# 3
# 18
# None

# %%
print(bad_add(4,2,1)**2)

# %%
# a function ends as soon as it encounters a return
def bad_add2(x,y,z): 
    return x
    return x+y+z
bad_add2(50,60,70)
# Out:
# 50

# %% [markdown]
# ### Trace function invocations to determine the flow of control

# %%
def func_c():
    print("C")
    
def func_b():
   print("B1")
   func_c()
   print("B2")

def func_a():
   print("A1")
   func_b()
   print("A2")

# %%
# call func_c

# %%
# call func_b

# %%
# call func_a

# %%
# what's wrong with this line?
func_a
# Out:
# <function __main__.func_a()>

# %%
# Explain the Worksheet, start part one of each problem
# this worksheet has questions that will be on your exam

# %% [markdown]
# # Announcements - Monday, October 2
#
# * Download ALL files for today's lecture
# * Exam 1
#   * General: Wednesday October 4: 5:45 pm
#   * McBurney: Wednesday October 4: 5:30 pm
#   * Alternate: Thursday October 5: 5:45 pm
#   * Room assignment via Canvas Message (let me (Gurmail.Singh@wisc.edu) know if you have not received any such message via Canvas)
#   * one page note sheet
#     * put anything you want on this sheet (both sides, written or printed)
#     * we will keep this sheet - make a copy if you want one
#   * Bring ID Card and #2 pencil
# * [Practice Exams](https://git.doit.wisc.edu/cdis/cs/courses/cs220/cs220-lecture-material/-/tree/main/f23/old_exams/exam1)
#
# * No Quiz this week

# %% [markdown]
# # Iteration Practice

# %% [markdown]
# ## Learning Objectives
#
# - Iterate through a dataset using for idx in range(project.count())
# - Compute the frequency of data that meets a certain criteria
# - Find the maximum or minimum value of a numeric column in a dataset
#     - Handle missing numeric values when computing a maximum / minimum
#     - Use the index of a maximum or minimum to access other information about that data item
# - Use break and continue in for loops when processing a dataset
# - Trace the output of a nested loop algorithm that prints out a game grid

# %%
import project

# %%
# TODO: inspect the functions inside project module
dir(project)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__init__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__student__',
#  'count',
#  'get_age',
#  'get_cats_or_dogs',
#  'get_lecture',
#  'get_other_majors',
#  'get_pizza_topping',
#  'get_primary_major',
#  'get_procrastinator',
#  'get_runner',
#  'get_section',
#  'get_sleep_habit',
#  'get_song',
#  'get_zip_code']

# %%
# TODO: inspect the project module's documentation
help(project)
# Out:
# Help on module project:
#
# NAME
#     project
#
# FUNCTIONS
#     __init__()
#
#     count()
#         This function will return the number of records in the dataset
#
#     get_age(idx)
#         get_age(idx) returns the age of the student in row idx
#
#     get_cats_or_dogs(idx)
#         get_cats_or_dogs(idx) returns whether student in row idx likes cats or dogs
#
#     get_lecture(idx)
#         get_lecture(idx) returns the lecture of the student in row idx
#
#     get_other_majors(idx)
#         get_other_majors(idx) returns the secondary major of the student in row idx
#
#     get_pizza_topping(idx)
#         get_pizza_topping(idx) returns the preferred pizza toppings of the student in row idx
#
#     get_primary_major(idx)
#         get_primary_major(idx) returns the primary major of the student in row idx
#
#     get_procrastinator(idx)
#         get_procrastinator(idx) returns whether student in row idx is a procrastinator
#
#     get_runner(idx)
#         get_runner(idx) returns whether student in row idx is a runner
#
#     get_section(idx)
#         get_lecture(idx) returns the section of the student in row idx
#
#     get_sleep_habit(idx)
#         get_sleep_habit(idx) returns the sleep habit of the student in row idx
#
#     get_song(idx)
#         get_procrastinator(idx) returns the student in row idx favorite song
#
#     get_zip_code(idx)
#         get_zip_code(idx) returns the residential zip code of the student in row idx
#
# DATA
#     __student__ = [{'Age': '19', 'Cats or dogs': 'cat', 'Latitude': '44.25...
#
# FILE
#     c:\users\drgsr\desktop\12_iteration_practice\project.py

# %% [markdown]
# ### How many students does the dataset have?

# %%
project.count()
# Out:
# 1019

# %% [markdown]
# ### What is the age of the student at index 11?

# %%
id_11_age = project.get_age(11)
id_11_age
# Out:
# '19'

# %%
# TODO: inspect return value type of get_age function
print(type(id_11_age))
# Out:
# <class 'str'>

# %% [markdown]
# ### What is the lecture number of the student at index 20?

# %%
project.get_lecture(20)
# Out:
# 'LEC003'

# %% [markdown]
# ### What is the sleep habit of the student at the last index?

# %%
project.get_sleep_habit(-1)
# Out:
# 'no preference'

# %%
project.get_sleep_habit(project.count() - 1)
# Out:
# 'no preference'

# %% [markdown]
# ### How many current lecture (example: LEC003) students are in the dataset?
#
# - use `for` loop to iterate over the dataset:
#     - `count` function gives you total number of students
#     - use `range` built-in function to generate sequence of integers from `0` to `count - 1`
# - use `get_lecture` to retrieve lecture column value
# - use `if` condition, to determine whether current student is part of `LEC003`
#     - `True` evaluation: increment count
#     - `False` evaluation: nothing to do

# %%
count = 0
for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    if lecture == "LEC003":
        count += 1
count
# Out:
# 230

# %% [markdown]
# ### What is the age of the oldest student in current lecture (example: LEC003)?
#
# - use `for` loop to iterate over the dataset just like last problem
# - use `get_age` to retrieve lecture column value
#     - if: age is '' (empty), move on to next student using `continue`
#     - make sure to typecast return value to an integer
# - use `get_lecture` to retrieve lecture column value
# - use `if` condition, to determine whether current student is part of `LEC003`
#     - use `if` condition to determine whether current student's age is greater than previously known max age
#         - `True` evaluation: replace previously known max age with current age
#         - `False` evaluation: nothing to do

# %%
max_age = 0

for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    age = project.get_age(idx)
    
    if age == '':
        continue
    age = int(age)
    
    if lecture == "LEC003":
        if age > max_age:
            max_age = age
max_age
# Out:
# 27

# %% [markdown]
# ### What is the age of the youngest student in current lecture (example: LEC003)?
# - use similar algorithm as above question

# %%
min_age = None

for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    age = project.get_age(idx)
    
    if age == '':
        continue
    age = int(age)
    
    if lecture == "LEC003":
        if min_age == None or age < min_age:
            min_age = age
min_age
# Out:
# 17

# %% [markdown]
# ### What is the average age of students enrolled in CS220 / CS319?
# - you will get an interesting answer :)
# - how can we ensure that data doesn't skew statistics?

# %%
# Incorrect version: skewed statistics
total_age = 0
count = 0

for idx in range(project.count()):
    age = project.get_age(idx)
    
    if age == '':
        continue
    age = int(age)
    total_age += age
    count += 1 # Be careful here: you cannot use the total count
    # Why? Because some students chose not to mention their age

print("Average student age is:", total_age / count)
# Out:
# Average student age is: 19.431578947368422

# %%
# Correct version with bounds check
total_age = 0
count = 0

for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    age = project.get_age(idx)
    
    if age == '':
        continue
    age = int(age)

    if age < 0 or age > 125:
        print("Age of some student who likes to have fun :) :", age)
        continue
    total_age += age
    count += 1 # Be careful here: you cannot use the total count
    # Why? Because some students chose not to mention their age

print("Average student age is:", total_age / count)
# Out:
# Average student age is: 19.431578947368422

# %% [markdown]
# ### What major is the youngest student in current lecture (example: LEC003) planning to declare?
# - now, we need to find some other detail about the youngest student
# - often, you'll have to keep track of ID of the max or min, so that you can retrive other details about that data entry

# %%
min_age = None
min_age_idx = None

for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    age = project.get_age(idx)
    
    if age == '':
        continue
    age = int(age)
    
    if lecture == "LEC003":
        if min_age == None or age < min_age:
            min_age = age
            min_age_idx = idx

project.get_primary_major(min_age_idx)
# Out:
# 'Data Science'

# %% [markdown]
# ### Considering current lecture students (example: LEC003), what is the age of the first student residing at zip code 53715?

# %%
search_age = None

for idx in range(project.count()):
    lecture = project.get_lecture(idx)
    age = project.get_age(idx)
    zipcode = project.get_zip_code(idx)
    
    if age == '' or zipcode == '':
        continue
    age = int(age)
    
    if lecture == "LEC003" and zipcode == "53,715":
        search_age = age
        break # you found the first such student, so you can terminate the loop execution

search_age

# %% [markdown]
# ## Self-practice

# %% [markdown]
# ### How many current lecture (example: LEC003) students are runners?

# %% [markdown]
# ### How many current lecture (example: LEC003) students are procrastinators?

# %% [markdown]
# ### How many current lecture (example: LEC003) students own or have owned a pet?

# %% [markdown]
# ### How many current lecture (example: LEC003) students like pineapple on their pizza?

# %% [markdown]
# ### What sleep habit does the youngest student in current lecture (example: LEC003) have?
# - try to solve this from scratch, instead of copy-pasting code to find mimimum age

# %% [markdown]
# ### What sleep habit does the oldest student in current lecture (example: LEC003) have?

# %% [markdown]
# ### What is the age of the youngest student residing in zip code 53706?

# %% [markdown]
# ### Considering current lecture students (example: LEC003), is the first student with age 18 a runner?

# %% [markdown]
# ### What is the minimum latitude (& corresponding longitude) of a student's place of interest?
# - What place is this -> try to enter the lat, long on Google maps?

# %% [markdown]
# ### What is the maximum latitude (& corresponding longitude) of a student's place of interest?
# - What place is this -> try to enter the lat, long on Google maps?

# %% [markdown]
# ### What is the minimum longitude (& corresponding latitude) of a student's place of interest?
# - What place is this -> try to enter the lat, long on Google maps?

# %% [markdown]
# ### What is the maximum longitude (& corresponding latitude) of a student's place of interest?
# - What place is this -> try to enter the lat, long on Google maps?

# %% [markdown]
# ### What song is alphabetically last in the data set?

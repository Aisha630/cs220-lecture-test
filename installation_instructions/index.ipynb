# %% [markdown]
# # Software Installation
#
# CS 220 uses **Jupyter Lab** to run Python code.  This development environment can be installed using **Pixi**.  Click on the appropriate link below and follow the instructions to install and setup this software on your Windows, MacOS or Linux computer.  If you have any problems with installation, bring your computer to lab or office hours to get support.
#
# ### <a href="macintosh/installation_instructions.html">Macintosh</a>
#
# ### <a href="windows/installation_instructions.html">Windows</a>
#
# ### <a href="linux/installation_instructions.html">Linux</a>
#
# #### Pixi Configuration File
#
# After installing pixi, you will need the following file to configure the course environment. Download the file and use it during installation.
#
# <a href="pixi.toml">pixi.toml</a>
